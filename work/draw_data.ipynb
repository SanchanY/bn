# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./230517_AI用qPCRデータ.xlsx", index_col=0)

# %%
df_new = df.T

# %%
df_new
# Out:
# gene       glk           agp      yihX           pgm      ptsG          malx  \
# 1     0.000004  2.982088e-05  0.000004  1.512045e-05  0.000015  9.403729e-07
# 2     0.000008  3.062644e-05  0.000016  2.940716e-08  0.000015  3.847846e-06
# 3     0.000008  7.608227e-06  0.000016  1.396326e-08  0.000031  9.615077e-07
# 4     0.000004  1.513944e-05  0.000015  1.225795e-07  0.000015  4.807837e-07
# 5     0.000008  4.768491e-07  0.000031  6.105349e-08  0.000031  9.593193e-07
# 6     0.000015  7.673560e-06  0.000015  1.244073e-07  0.000032  1.933798e-06
# 7     0.000008  3.074730e-05  0.000016  7.638838e-09  0.000032  1.937585e-06
#
# gene       crr      galM          yihR      yeaD  ...      tpiA      gapA  \
# 1     0.000122  0.000015  4.792578e-07  0.000007  ...  0.000008  0.000121
# 2     0.000124  0.000015  3.848767e-06  0.000015  ...  0.000015  0.000123
# 3     0.000245  0.000015  4.864569e-07  0.000031  ...  0.000015  0.000122
# ...

# %%
df_new['glk'].plot.bar(figsize=(24, 12))

plt.title("glucokinase")
# Out:
# Text(0.5, 1.0, 'glucokinase')

# %%
df_new.round(20)
# Out:
# gene                    glk                    agp                   yihX  \
# 1    0.00000371298258509107 0.00002982088159210874 0.00000368577003649490
# 2    0.00000767679194154582 0.00003062644498462545 0.00001550379245933209
# 3    0.00000767037013593577 0.00000760822692515504 0.00001555514067554962
# 4    0.00000385268222071600 0.00001513943932272368 0.00001535579653988266
# 5    0.00000773386437449207 0.00000047684913621364 0.00003109627973841944
# 6    0.00001548747508260417 0.00000767356005272872 0.00001548903130469170
# 7    0.00000766620337734212 0.00003074730384323172 0.00001562488867845353
#
# gene                    pgm                   ptsG                   malx  \
# 1    0.00001512044657734958 0.00001527542086823572 0.00000094037291880119
# 2    0.00000002940715501813 0.00001547575724169344 0.00000384784639517946
# 3    0.00000001396325855020 0.00003149073874418706 0.00000096150768186820
# 4    0.00000012257951302703 0.00001549827971695125 0.00000048078371467824
# ...

# %%
df_new.round(20).to_csv("./data.csv")

# %%
df = pd.read_csv("./data.csv", index_col=0)

# %%
df = df * 100   # 100倍して表示

# %%
df.max().max()
# Out:
# 0.02523565978378

# %%
display(df.iloc[:, 0:5].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 5:10].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 10:15].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 15:20].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 20:25].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 25:30].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
display(df.iloc[:, 30:35].plot.bar(figsize=(24, 12), ylim=[0, 0.026]))
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>
# <AxesSubplot:>

# %%
df.iloc[:, :].plot.bar(figsize=(24, 12))
# Out:
# <AxesSubplot:>
